# %%
import pandas as pd
from ctgan import CTGAN

# %%
data =pd.read_csv("Credit_Data.csv")

# %%
data
# Out:
#            Date        Open        High         Low       Close     Volume  \
# 0    2019-05-21   39.551998   41.480000   39.208000   41.015999   90019500
# 1    2019-05-22   39.820000   40.787998   38.355999   38.546001   93426000
# 2    2019-05-23   38.868000   39.894001   37.243999   39.098000  132735500
# 3    2019-05-24   39.966000   39.995998   37.750000   38.125999   70683000
# 4    2019-05-28   38.240002   39.000000   37.570000   37.740002   51564500
# ..          ...         ...         ...         ...         ...        ...
# 753  2022-05-16  767.159973  769.760010  719.090027  724.369995   28699500
# 754  2022-05-17  747.359985  764.479980  728.849976  761.609985   26745400
# 755  2022-05-18  744.520020  760.500000  700.809998  709.809998   29270600
# 756  2022-05-19  707.000000  734.000000  694.109985  709.419983   30098900
# 757  2022-05-20  713.989990  721.580017  633.000000  663.900024   48190600
#
#      Dividends  Stock Splits
# 0            0           0.0
# 1            0           0.0
# 2            0           0.0
# 3            0           0.0
# 4            0           0.0
# ..         ...           ...
# 753          0           0.0
# 754          0           0.0
# 755          0           0.0
# 756          0           0.0
# 757          0           0.0
#
# [758 rows x 8 columns]

# %%
data = data.drop('Date',axis=1 ,inplace=True)

# %%
ctgan = CTGAN(verbose=True)
ctgan.fit(data,epochs= 200)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 ctgan = CTGAN(verbose=True)
# ----> 2 ctgan.fit(data,epochs= 200)
#
# File c:\Python\Python311\Lib\site-packages\ctgan\synthesizers\base.py:50, in random_state.<locals>.wrapper(self, *args, **kwargs)
#      48 def wrapper(self, *args, **kwargs):
#      49     if self.random_states is None:
# ---> 50         return function(self, *args, **kwargs)
#      52     else:
#      53         with set_random_states(self.random_states, self.set_random_state):
#
# File c:\Python\Python311\Lib\site-packages\ctgan\synthesizers\ctgan.py:293, in CTGAN.fit(self, train_data, discrete_columns, epochs)
#     280 @random_state
#     281 def fit(self, train_data, discrete_columns=(), epochs=None):
#     282     """Fit the CTGAN Synthesizer models to the training data.
#     283
#     284     Args:
#    (...)
#     291             a ``pandas.DataFrame``, this list should contain the column names.
#     292     """
# --> 293     self._validate_discrete_columns(train_data, discrete_columns)
#     295     if epochs is None:
#     296         epochs = self._epochs
#
# File c:\Python\Python311\Lib\site-packages\ctgan\synthesizers\ctgan.py:275, in CTGAN._validate_discrete_columns(self, train_data, discrete_columns)
#     273             invalid_columns.append(column)
#     274 else:
# --> 275     raise TypeError('``train_data`` should be either pd.DataFrame or np.array.')
#     277 if invalid_columns:
#     278     raise ValueError(f'Invalid columns found: {invalid_columns}')
#
# TypeError: ``train_data`` should be either pd.DataFrame or np.array.
